# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../coco_dataset')

from coco_handler import *

# %%
image_data, removed_image_ids = get_image_data(annotations_file, images_dir)
image_detections = get_image_detections(annotations_file, removed_image_ids)
detection_data = get_detection_data(image_data, image_detections)

# %%
import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
cifar_image_detections = {}
cifar_detection_data = {}

for i in range(x_train.shape[0]):
    bbox_dict = {
        'category_id': int(y_train[i])
    }
    
    cifar_image_detections[i] = {
        i: bbox_dict
    }
    
    cifar_detection_data[i] = x_train[i]

LABEL_MAP = {
    0: 'airplane',
    1:'automobile',
    2:'bird',
    3:'cat',
    4:'deer',
    5:'dog',
    6:'frog',
    7:'horse',
    8:'ship',
    9:'truck'
}

cifar_detection_data = cifar_detection_data.copy() 

for k,v in cifar_detection_data.items():
    cifar_detection_data[k] = v / 255.

# %%
import data_handler

import importlib
importlib.reload(data_handler)
import data_handler

   
target_classes = ['person', 'motorcycle', 'bicycle', 'car', 'bus', 'truck', 'bird', 'cat', 'dog', 'horse', 'sheep', 'handbag', 'umbrella', 'backpack' 'hot dog', 'pizza', 'donut']
target_classes = None

data_handler_obj = data_handler.DataHandler(
    cifar_image_detections, 
    cifar_detection_data, 
    target_classes = target_classes, 
    label_map = LABEL_MAP
)

data_handler_obj.add_augmentation(flip=True, rotation=True, translation=True, zoom=True, contrast=False)

all_object_categories = data_handler_obj.get_all_object_categories()
print(len(all_object_categories), set(all_object_categories))
# Out:
# 50000 {'ship', 'deer', 'truck', 'cat', 'horse', 'bird', 'dog', 'airplane', 'frog', 'automobile'}

# %%
x,y = data_handler_obj.create_batch()
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16, 16))
plt.axis('off')

columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = x[i]
    subplot = fig.add_subplot(rows, columns, i)
    subplot.title.set_text('{} - context: {}'.format(LABEL_MAP.get(y[i][0]), y[i][1]))
    subplot.set_axis_off()
    plt.imshow(img)
plt.show()

# %%
import importlib
import model_handler
importlib.reload(model_handler)
# Out:
# <module 'model_handler' from 'E:\\Projects\\Code\\Disertation\\Code\\feature_learner\\model_handler.py'>

# %%
model_name = 'FULL_TRAIN_autoencoder_and_tripletloss_cifar10_1631077670.804196'

data_handler_obj.remove_augmentation()

model_handler.generate_projector_files(model_name, data_handler_obj, LABEL_MAP, no_samples = 5000, max_category_samples = 400, doublehead_model = True)
# Out:
# {'bird': 491, 'automobile': 489, 'cat': 537, 'airplane': 474, 'ship': 486, 'horse': 480, 'frog': 504, 'deer': 503, 'truck': 500, 'dog': 528}
# 3990

# %%
model_handler.evaluate(model_name, data_handler_obj, LABEL_MAP, no_samples = 2000)
# Out:
# {'cat_cat': 0.6552479054007614, 'pizza_cat': 0.6114889401879776, 'bicycle_cat': 0.5916145267829128, 'car_cat': 0.6078623858595187, 'motorcycle_cat': 0.630434331127441, 'bus_cat': 0.6374814989361711, 'truck_cat': 0.6124820177777004, 'donut_cat': 0.5916130952782102, 'dog_cat': 0.5963043715817233, 'bird_cat': 0.6439146494522862, 'pizza_pizza': 0.5084873335770886, 'bicycle_pizza': 0.5408799550282918, 'car_pizza': 0.5442543486508471, 'motorcycle_pizza': 0.5800579297613336, 'bus_pizza': 0.5831674213607264, 'truck_pizza': 0.5485262715949938, 'donut_pizza': 0.49947148701157235, 'dog_pizza': 0.5343560076892526, 'bird_pizza': 0.5753039798984458, 'bicycle_bicycle': 0.4735219987773591, 'car_bicycle': 0.5016063936447174, 'motorcycle_bicycle': 0.5307542187676337, 'bus_bicycle': 0.5502180693003262, 'truck_bicycle': 0.5287703578120928, 'donut_bicycle': 0.5323978358380411, 'dog_bicycle': 0.5180418341157251, 'bird_bicycle': 0.6004924867035518, 'car_car': 0.5137860235802323, 'motorcycle_car': 0.5508977679926602, 'bus_car': 0.5672946994913246, 'truck_car': 0.5383285886190902, 'donut_car': 0.5349917749287161, 'dog_car': 0.531082439000484, 'bird_car': 0.599639237965795, 'motorcycle_motorcycle': 0.5679182513424352, 'bus_motorcycle': 0.5876931449225546, 'truck_motorcycle': 0.5629161751374616, 'donut_motorcycle': 0.5694364409009804, 'dog_motorcycle': 0.5555188873597372, 'bird_motorcycle': 0.619391014418545, 'bus_bus': 0.5758101112426377, 'truck_bus': 0.5641252105107019, 'donut_bus': 0.5704505601995308, 'dog_bus': 0.5573510906629024, 'bird_bus': 0.5994455849202774, 'truck_truck': 0.5263888519866536, 'donut_truck': 0.5392276438071482, 'dog_truck': 0.5297240834895587, 'bird_truck': 0.5621328666550807, 'donut_donut': 0.4649796293139721, 'dog_donut': 0.5182223124789695, 'bird_donut': 0.5575389156965004, 'dog_dog': 0.507273330003667, 'bird_dog': 0.5561057174263586, 'bird_bird': 0.52652829976565}

# %%
import importlib
import model_handler
importlib.reload(model_handler)

model_handler.create_doublehead_model(input_shape = (32,32,3), embedding_size = 128, model_name = 'doublehead_model')
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# =================================================================
# Total params: 5,217,600
# Trainable params: 5,213,760
# Non-trainable params: 3,840
# _________________________________________________________________
# 2048
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 256)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              526336
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_transpose_16 (Conv2DT (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_transpose_15 (Conv2DT (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 8, 8, 256)         1179904
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 16, 16, 128)       295040
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_transpose_11 (Conv2DT (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_transpose_10 (Conv2DT (None, 32, 32, 64)        73792
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_transpose_9 (Conv2DTr (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_transpose_17 (Conv2DT (None, 32, 32, 3)         1731
# =================================================================
# Total params: 7,578,691
# Trainable params: 7,574,851
# Non-trainable params: 3,840
# _________________________________________________________________
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               5217600
# _________________________________________________________________
# decoder (Functional)         (None, 32, 32, 3)         7578691
# =================================================================
# Total params: 12,796,291
# Trainable params: 12,788,611
# Non-trainable params: 7,680
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: .\models\doublehead_model\assets

# %%
model_handler.train_model(
    'doublehead_model', 
    data_handler_obj, 
    new_model_name = 'tripletloss_cifar10', 
    no_epochs = 30, 
    steps_per_epoch = None, 
    learning_rate = 0.01, 
    entity_loss_weight = 1, 
    context_loss_weight = 0,
    reconstruction_loss_weight = 0,
    freeze_backbone = False, 
    doublehead = True
)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# INFO:tensorflow:Assets written to: .\models\autoencoder_1630998279.8663526\assets
# Epoch 28/30
# 1562/1562 [==============================] - 278s 178ms/step - loss: 0.2700 - encoder_loss: 0.0000e+00 - decoder_loss: 0.0027 4:33 - loss: 0.3014  - ETA: 4:25 - loss: 0.2900  - ETA: 14s - loss: 0.2682 - ETA: 9s - loss: 0.2685 - encoder_loss: 0.0000e+00 - decoder - ETA: 7s - loss: 0.2685 - encoder_loss: 0.000 - ETA: 2s - loss: 0.2696 - encoder_loss: 0.0000e+00 - decode
# INFO:tensorflow:Assets written to: .\models\autoencoder_1630998279.8663526\assets
# Epoch 29/30
# 1562/1562 [==============================] - 277s 178ms/step - loss: 0.2657 - encoder_loss: 0.0000e+00 - decoder_loss: 0.0027
# INFO:tensorflow:Assets written to: .\models\autoencoder_1630998279.8663526\assets
# Epoch 30/30
# 1562/1562 [==============================] - 278s 178ms/step - loss: 0.2641 - encoder_loss: 0.0000e+00 - decoder_loss: 0.0026s - loss: 0.2642 - encoder_loss: 0.0000e+00 - deco
# INFO:tensorflow:Assets written to: .\models\autoencoder_1630998279.8663526\assets
# INFO:tensorflow:Assets written to: .\models\autoencoder_1630998279.8663526\assets

# %%
model_handler.train_model(
    'doublehead_model', 
    data_handler_obj, 
    new_model_name = 'doublehead_tripletloss_autoencoder', 
    no_epochs = 50, 
    steps_per_epoch = None, 
    learning_rate = 0.01, 
    entity_loss_weight = 1, 
    context_loss_weight = 0,
    reconstruction_loss_weight = 1,
    freeze_backbone = False, 
    doublehead = True
)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               5217600
# _________________________________________________________________
# decoder (Functional)         (None, 32, 32, 3)         7578691
# =================================================================
# Total params: 12,796,291
# Trainable params: 12,788,611
# Non-trainable params: 7,680
# _________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-82d86d0536d0> in <module>
#      10     reconstruction_loss_weight = 1,
#      11     freeze_backbone = False,
# ---> 12     doublehead = True
#      13 )
#
# E:\Projects\Code\Disertation\Code\feature_learner\model_handler.py in train_model(model_name, data_handler, new_model_name, steps_per_epoch, no_epochs, learning_rate, entity_loss_weight, context_loss_weight, freeze_backbone, doublehead, reconstruction_loss_weight)
#     325     model.summary()
#     326
# --> 327     input("Press Enter to continue...")
#     328
#     329     model.fit(
#
# c:\users\tdr_v\anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     849             self._parent_ident,
#     850             self._parent_header,
# --> 851             password=False,
#     852         )
#     853
#
# c:\users\tdr_v\anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
data_handler_obj.remove_augmentation()

x,y = data_handler_obj.create_batch(16)
pred = model_handler.predict('FULL_TRAIN_tripletloss_cifar10_1631077539.1865098', x)

fig = plt.figure(figsize=(16, 16))
plt.axis('off')

reconstructed_images = pred[1]

columns = 2
rows = 4
for i in range(rows):
    img = x[i]
    reconstructed_img = reconstructed_images[i]
    
    subplot = fig.add_subplot(rows, columns, i * 2 + 1)
    subplot.title.set_text('Original Image ({})'.format(LABEL_MAP.get(y[i][0])))
    subplot.set_axis_off()
    plt.imshow(img)
    
    subplot = fig.add_subplot(rows, columns, i * 2 + 2)
    subplot.title.set_text('Reconstructed Image')
    subplot.set_axis_off()
    plt.imshow(reconstructed_img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(pred[1].shape)
# Out:
# (16, 32, 32, 3)

# %%
plt.imshow(pred[1][0])
#plt.imshow(x[0])

#print(pred[1][0])
